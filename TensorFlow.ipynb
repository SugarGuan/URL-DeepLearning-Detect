# %%
from keras.datasets import imdb
(train_data, train_labels),(test_data, test_lables) = imdb.load_data(
    num_words=10000
)
#num-words controlls that use less words are not included.

train_data[0]
# train data is one record for a remark.
# The number is the key of signgle non-repeated word.
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
# ...

# %%
len(train_data[0])
# Remark sentense have 218 high senstive words.
# Out:
# 218

# %%
train_labels[0]  # 1 means remarks here positive
# Out:
# 1

# %%
maxcount = 0
maxi = 0
for i in range(len(train_data)):
    if len(train_data[i]) > maxcount:
        maxcount = len(train_data[i])
        maxi = i

# %%
print(maxcount)
print(maxi)
# Out:
# 2494
# 17934

# %%
train_data[17934]
# Out:
# [1,
#  1014,
#  300,
#  4349,
#  768,
#  2702,
#  1014,
#  2,
#  1538,
#  5,
#  3483,
#  5934,
#  1918,
#  1812,
#  2,
#  5,
#  1378,
#  9125,
#  2,
#  1538,
#  5,
#  3483,
#  5934,
#  645,
#  183,
#  125,
#  19,
#  6,
#  4349,
#  768,
#  2702,
#  1014,
#  429,
#  1812,
#  2,
#  5,
#  1378,
#  9125,
#  1793,
#  8,
#  4,
#  2269,
#  7,
#  4,
#  1014,
#  199,
#  9149,
#  28,
#  8,
#  140,
#  143,
#  8915,
#  11,
#  661,
#  8,
#  79,
#  4,
#  1176,
#  9125,
#  5,
#  2,
#  2,
#  56,
#  402,
#  23,
#  34,
#  656,
#  505,
#  2,
#  86,
#  3483,
#  5,
#  95,
#  2,
#  1538,
#  6,
#  1124,
#  2,
#  34,
#  9125,
#  8,
#  2,
#  562,
#  4,
#  1933,
#  46,
#  7,
#  4,
#  5934,
#  597,
#  3483,
#  805,
#  8,
#  339,
#  27,
#  597,
#  21,
#  4,
#  2,
#  6075,
#  90,
#  137,
#  9125,
#  5,
#  2,
#  2,
#  56,
#  23,
#  90,
#  11,
#  4,
#  3130,
#  19,
#  9125,
#  2,
#  245,
#  23,
#  2,
#  2,
#  270,
#  56,
#  6,
#  2702,
#  1005,
#  3483,
#  2,
#  83,
#  4,
#  1746,
#  5,
#  2,
#  120,
#  4,
#  350,
# ...

# %%
len(train_data[17934])
# Out:
# 2494

# %%
train_data
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...
